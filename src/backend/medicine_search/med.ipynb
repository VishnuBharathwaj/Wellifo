# %%
import pandas as pd

def search_medicine(medicine_name, file_path):
    df = pd.read_csv(file_path)
    result = df[df['name'].str.lower() == medicine_name.lower()]
    if result.empty:
        return "Medicine not found."
    return result.to_dict(orient='records')[0]

# Example usage
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
medicine_name = input("Enter medicine name: ")
details = search_medicine(medicine_name, file_path)
print(details)
# Out:
# Medicine not found.

# %%
import pandas as pd

def search_medicine(medicine_prefix, file_path):
    df = pd.read_csv(file_path)
    result = df[df['name'].str.lower().str.startswith(medicine_prefix.lower())]
    if result.empty:
        return "No medicines found with this prefix."
    return result.to_dict(orient='records')

# Example usage
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
medicine_prefix = input("Enter medicine prefix: ")
details = search_medicine(medicine_prefix, file_path)
print(details)

# %%
pip install readline
# Out:
# ...
#   Using cached readline-6.2.4.1.tar.gz (2.3 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       error: this module is not meant to work on Windows
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install prompt_toolkit
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import sys
from prompt_toolkit import prompt
from prompt_toolkit.completion import WordCompleter

def search_medicine(medicine_prefix, file_path):
    df = pd.read_csv(file_path)
    suggestions = df[df['name'].str.lower().str.startswith(medicine_prefix.lower())]['name'].tolist()
    return suggestions if suggestions else ["No suggestions"]

# Example usage
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
medicine_completer = WordCompleter(df['name'].dropna().astype(str).tolist(), ignore_case=True)

while True:
    try:
        # Use prompt_toolkit only if running in a standard terminal
        if sys.stdin.isatty():
            medicine_prefix = prompt("Start typing medicine name: ", completer=medicine_completer)
        else:
            medicine_prefix = input("Start typing medicine name: ")
        suggestions = search_medicine(medicine_prefix, file_path)
        print("Suggestions:", suggestions)
    except KeyboardInterrupt:
        print("\nExiting...")
        break
# Out:
# Suggestions: ['Augmentin 625 Duo Tablet', 'Augmentin Duo Oral Suspension', 'Augmentin DDS Suspension', 'Augmentin 1000 Duo Tablet', 'Augmentin 375 Tablet', 'Augmentin 1.2gm Injection', 'Augmentin ES Oral Suspension', 'AUGMENTIN 375 DUO TABLET', 'Augmentin 500mg/100mg Injection', 'Augmentin 250mg/50mg Injection']
# Suggestions: ['Augmentin 625 Duo Tablet', 'Augmentin Duo Oral Suspension', 'Augmentin DDS Suspension', 'Augmentin 1000 Duo Tablet', 'Augmentin 375 Tablet', 'Augmentin 1.2gm Injection', 'Augmentin ES Oral Suspension', 'AUGMENTIN 375 DUO TABLET', 'Augmentin 500mg/100mg Injection', 'Augmentin 250mg/50mg Injection']
# Suggestions: ['Augmentin 625 Duo Tablet']

# %%
import pandas as pd
from prompt_toolkit import prompt
from prompt_toolkit.completion import WordCompleter

def search_medicine(medicine_prefix, df):
    filtered_df = df[df['name'].str.lower().str.startswith(medicine_prefix.lower())]
    if not filtered_df.empty:
        return filtered_df.to_string(index=False)
    return "No matching medicines found."

# Load CSV
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
medicine_completer = WordCompleter(df['name'].dropna().astype(str).tolist(), ignore_case=True)

while True:
    medicine_prefix = prompt("Start typing medicine name: ", completer=medicine_completer)
    result = search_medicine(medicine_prefix, df)
    print(result)
# Out:
# ---------------------------------------------------------------------------
# NoConsoleScreenBufferError                Traceback (most recent call last)
# Cell In[2], line 17
#      14 medicine_completer = WordCompleter(df['name'].dropna().astype(str).tolist(), ignore_case=True)
#      16 while True:
# ---> 17     medicine_prefix = prompt("Start typing medicine name: ", completer=medicine_completer)
#      18     result = search_medicine(medicine_prefix, df)
#      19     print(result)
#
# ...

# %%
import pandas as pd
from prompt_toolkit import prompt
from prompt_toolkit.completion import WordCompleter
from prompt_toolkit.input.defaults import create_input
from prompt_toolkit.output.defaults import create_output

# Load dataset
dataset_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(dataset_path)

# Ensure 'name' column exists
if 'name' not in df.columns:
    raise ValueError("CSV file must contain a 'name' column")

medicine_completer = WordCompleter(df['name'].dropna().astype(str).tolist(), ignore_case=True)

def search_medicine(query, dataframe):
    result = dataframe[dataframe['name'].str.contains(query, case=False, na=False)]
    return result if not result.empty else "No match found."

while True:
    medicine_prefix = prompt(
        "Start typing medicine name: ",
        completer=medicine_completer,
        input=create_input(),
        output=create_output()
    )
    if medicine_prefix.lower() == 'exit':
        break
    result = search_medicine(medicine_prefix, df)
    print(result)
# Out:
# ---------------------------------------------------------------------------
# NoConsoleScreenBufferError                Traceback (most recent call last)
# Cell In[3], line 26
#      19     return result if not result.empty else "No match found."
#      21 while True:
#      22     medicine_prefix = prompt(
#      23         "Start typing medicine name: ",
#      24         completer=medicine_completer,
#      25         input=create_input(),
# ---> 26         output=create_output()
#      27     )
#      28     if medicine_prefix.lower() == 'exit':
#      29         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\prompt_toolkit\output\defaults.py:87, in create_output(stdout, always_prefer_tty)
#      83         return cast(
#      84             Output, ConEmuOutput(stdout, default_color_depth=color_depth_from_env)
#      85         )
#      86     else:
# ...

# %%
import pandas as pd

# Load dataset
dataset_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(dataset_path)

# Ensure 'name' column exists
if 'name' not in df.columns:
    raise ValueError("CSV file must contain a 'name' column")

def search_medicine(query, dataframe):
    result = dataframe[dataframe['name'].str.contains(query, case=False, na=False)]
    return result if not result.empty else "No match found."

while True:
    medicine_prefix = input("Start typing medicine name (or type 'exit' to quit): ").strip()
    if medicine_prefix.lower() == 'exit':
        break
    result = search_medicine(medicine_prefix, df)
    print(result)
# Out:
#         id                                   name   price  Is_discontinued  \
# 2        3                       Ascoril LS Syrup  118.00            False
# 9       10        Ascoril D Plus Syrup Sugar Free  129.00            False
# 24      25                Ascoril LS Junior Syrup   96.00            False
# 59      60                       Ascoril LS Drops   72.00            False
# 67      68           Ascoril D Junior Cough Syrup   98.00            False
# 136    137                 Ascoril SF Expectorant  135.00            False
# 158    159               Ascoril Plus Expectorant  182.00             True
# 194    195                       Ascoril C  Syrup  174.00            False
# 201    202                      Ascoril Flu Syrup   87.50             True
# 287    288                    Ascoril Expectorant  142.00             True
# 298    299               Ascoril Plus Expectorant  129.00            False
# ...

# %%
import pandas as pd
from prompt_toolkit import prompt
from prompt_toolkit.completion import WordCompleter

# Load dataset
dataset_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(dataset_path)

# Ensure 'name' column exists
if 'name' not in df.columns:
    raise ValueError("CSV file must contain a 'name' column")

# Medicine name auto-completer
medicine_completer = WordCompleter(df['name'].dropna().unique(), ignore_case=True)

def search_medicine(query, dataframe):
    result = dataframe[dataframe['name'].str.contains(query, case=False, na=False)]
    return result if not result.empty else "No match found."

while True:
    medicine_prefix = prompt("Start typing medicine name: ", completer=medicine_completer).strip()
    if medicine_prefix.lower() == 'exit':
        break
    result = search_medicine(medicine_prefix, df)
    print(result)
# Out:
# ---------------------------------------------------------------------------
# NoConsoleScreenBufferError                Traceback (most recent call last)
# Cell In[5], line 21
#      18     return result if not result.empty else "No match found."
#      20 while True:
# ---> 21     medicine_prefix = prompt("Start typing medicine name: ", completer=medicine_completer).strip()
#      22     if medicine_prefix.lower() == 'exit':
#      23         break
#
# ...

# %%
import pandas as pd
import joblib
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)

# Train and save the model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['name'].astype(str))
model = NearestNeighbors(n_neighbors=5, metric='cosine')
model.fit(X)

joblib.dump((vectorizer, model), "C:\Users\HP\Downloads\medicine search\medicine_recommender.pkl")

# UI for search with live recommendation
def update_suggestions(*args):
    query = search_var.get()
    if query:
        query_vector = vectorizer.transform([query])
        distances, indices = model.kneighbors(query_vector)
        suggestions = df.iloc[indices[0]]['name'].tolist()
        listbox.delete(0, tk.END)
        for suggestion in suggestions:
            listbox.insert(tk.END, suggestion)

def display_details(event):
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'] == medicine_name].iloc[0]
        details_text.set(f"Name: {details['name']}\nPrice: {details['price']}\nManufacturer: {details['manufacturer_name']}\nType: {details['type']}\nComposition: {details['salt_composition']}\nDescription: {details['medicine_desc']}\nSide Effects: {details['side_effects']}")

root = tk.Tk()
root.title("Medicine Search")
search_var = tk.StringVar()
search_var.trace("w", update_suggestions)

search_entry = ttk.Entry(root, textvariable=search_var, width=50)
search_entry.pack(pady=10)

listbox = tk.Listbox(root, width=50, height=5)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

details_text = tk.StringVar()
details_label = ttk.Label(root, textvariable=details_text, justify=tk.LEFT, anchor="w")
details_label.pack(pady=10)

root.mainloop()
# Out:
#   Cell In[5], line 19
#     joblib.dump((vectorizer, model), "C:\Users\HP\Downloads\medicine search\medicine_recommender.pkl")
#                                                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import joblib
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)

# Train and save the model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['name'].astype(str))
model = NearestNeighbors(n_neighbors=5, metric='cosine')
model.fit(X)

joblib.dump((vectorizer, model), r"C:\Users\HP\Downloads\medicine search\medicine_recommender.pkl")

# UI for search with live recommendation
def update_suggestions(*args):
    query = search_var.get()
    if query:
        query_vector = vectorizer.transform([query])
        distances, indices = model.kneighbors(query_vector)
        suggestions = df.iloc[indices[0]]['name'].tolist()
        listbox.delete(0, tk.END)
        for suggestion in suggestions:
            listbox.insert(tk.END, suggestion)

def display_details(event):
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'] == medicine_name].iloc[0]
        details_text.set(f"Name: {details['name']}\nPrice: {details['price']}\nManufacturer: {details['manufacturer_name']}\nType: {details['type']}\nComposition: {details['salt_composition']}\nDescription: {details['medicine_desc']}\nSide Effects: {details['side_effects']}")

root = tk.Tk()
root.title("Medicine Search")
search_var = tk.StringVar()
search_var.trace("w", update_suggestions)

search_entry = ttk.Entry(root, textvariable=search_var, width=50)
search_entry.pack(pady=10)

listbox = tk.Listbox(root, width=50, height=5)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

details_text = tk.StringVar()
details_label = ttk.Label(root, textvariable=details_text, justify=tk.LEFT, anchor="w")
details_label.pack(pady=10)

root.mainloop()

# %%
import pandas as pd
import joblib
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
df.fillna("Not Available", inplace=True)  # Replace NaN values with "Not Available"

# Train and save the model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['name'].astype(str))
model = NearestNeighbors(n_neighbors=5, metric='cosine')
model.fit(X)

joblib.dump((vectorizer, model), r"C:\Users\HP\Downloads\medicine search\medicine_recommender.pkl")

# UI for search with live recommendation
def update_suggestions(*args):
    query = search_var.get().strip().lower()
    if query:
        query_vector = vectorizer.transform([query])
        distances, indices = model.kneighbors(query_vector)
        suggestions = df.iloc[indices[0]]['name'].tolist()
        listbox.delete(0, tk.END)
        for suggestion in suggestions:
            listbox.insert(tk.END, suggestion)

def display_details(event):
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'].str.lower() == medicine_name.lower()].iloc[0]
        details_text.set(f"Name: {details['name']}\nPrice: {details['price']}\nManufacturer: {details['manufacturer_name']}\nType: {details['type']}\nComposition: {details['salt_composition']}\nDescription: {details['medicine_desc']}\nSide Effects: {details['side_effects']}")

root = tk.Tk()
root.title("Medicine Search")
search_var = tk.StringVar()
search_var.trace("w", update_suggestions)

search_entry = ttk.Entry(root, textvariable=search_var, width=30)
search_entry.pack(pady=10)

listbox = tk.Listbox(root, width=30, height=10)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

details_text = tk.StringVar()
details_label = ttk.Label(root, textvariable=details_text, justify=tk.LEFT, anchor="w")
details_label.pack(pady=10)

root.mainloop()

# %%
import pandas as pd
import joblib
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
df.fillna("Not Available", inplace=True)  # Replace NaN values with "Not Available"

# Train and save the model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['name'].astype(str))
model = NearestNeighbors(n_neighbors=10, metric='cosine')  # Increased neighbors for better matching
model.fit(X)

joblib.dump((vectorizer, model), r"C:\Users\HP\Downloads\medicine search\medicine_recommender.pkl")

# UI for search with live recommendation
def update_suggestions(*args):
    query = search_var.get().strip().lower()
    if query:
        filtered_df = df[df['name'].str.lower().str.startswith(query)]
        suggestions = filtered_df['name'].tolist()
        listbox.delete(0, tk.END)
        for suggestion in suggestions:
            listbox.insert(tk.END, suggestion)


def display_details(event):
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'].str.lower() == medicine_name.lower()].iloc[0]
        details_text.set(f"Name: {details['name']}\nPrice: {details['price']}\nManufacturer: {details['manufacturer_name']}\nType: {details['type']}\nComposition: {details['salt_composition']}\nDescription: {details['medicine_desc']}\nSide Effects: {details['side_effects']}")

root = tk.Tk()
root.title("Medicine Search")
search_var = tk.StringVar()
search_var.trace("w", update_suggestions)

search_entry = ttk.Entry(root, textvariable=search_var, width=50)
search_entry.pack(pady=10)

listbox = tk.Listbox(root, width=50, height=5)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

details_text = tk.StringVar()
details_label = ttk.Label(root, textvariable=details_text, justify=tk.LEFT, anchor="w")
details_label.pack(pady=10)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 56
#      53 details_label = ttk.Label(root, textvariable=details_text, justify=tk.LEFT, anchor="w")
#      54 details_label.pack(pady=10)
# ---> 56 root.mainloop()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\tkinter\__init__.py:1504, in Misc.mainloop(self, n)
#    1502 def mainloop(self, n=0):
#    1503     """Call the mainloop of Tk."""
# -> 1504     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import joblib
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
df.fillna("Not Available", inplace=True)  # Replace NaN values with "Not Available"

# UI for displaying medicine details
def display_details(event):
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'].str.lower() == medicine_name.lower()].iloc[0]
        details_text.set(f"Name: {details['name']}\n"
                         f"Price: {details['price']}\n"
                         f"Manufacturer: {details['manufacturer_name']}\n"
                         f"Type: {details['type']}\n"
                         f"Composition: {details['salt_composition']}\n\n"
                         f"Description:\n{details['medicine_desc']}\n\n"
                         f"Side Effects:\n{details['side_effects']}")

        # Remove the search bar after selection
        search_entry.pack_forget()
        listbox.pack_forget()

root = tk.Tk()
root.title("Medicine Search")

search_var = tk.StringVar()

search_entry = ttk.Entry(root, textvariable=search_var, width=50)
search_entry.pack(pady=10)

listbox = tk.Listbox(root, width=50, height=5)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

details_text = tk.StringVar()
details_label = ttk.Label(root, textvariable=details_text, justify=tk.LEFT, anchor="w", wraplength=600)
details_label.pack(pady=10)

root.mainloop()

# %%
import pandas as pd
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
df.fillna("Not Available", inplace=True)  # Replace NaN values with "Not Available"

def update_suggestions(*args):
    """Update the listbox with medicine names matching the search query."""
    query = search_var.get().strip().lower()
    if query:
        filtered_df = df[df['name'].str.lower().str.startswith(query)]
        suggestions = filtered_df['name'].tolist()
        listbox.delete(0, tk.END)
        for suggestion in suggestions:
            listbox.insert(tk.END, suggestion)

def display_details(event):
    """Display medicine details and hide search UI after selection."""
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'].str.lower() == medicine_name.lower()].iloc[0]
        details_text.set(f"Name: {details['name']}\n"
                         f"Price: {details['price']}\n"
                         f"Manufacturer: {details['manufacturer_name']}\n"
                         f"Type: {details['type']}\n"
                         f"Composition: {details['salt_composition']}\n\n"
                         f"Description:\n{details['medicine_desc']}\n\n"
                         f"Side Effects:\n{details['side_effects']}")

        # Hide search UI after selection
        search_entry.pack_forget()
        listbox.pack_forget()

root = tk.Tk()
root.title("Medicine Search")

search_var = tk.StringVar()
search_var.trace("w", update_suggestions)

# Search Entry
search_entry = ttk.Entry(root, textvariable=search_var, width=50)
search_entry.pack(pady=10)

# Listbox for displaying suggestions
listbox = tk.Listbox(root, width=50, height=5)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

# Label to display medicine details
details_text = tk.StringVar()
details_label = ttk.Label(root, textvariable=details_text, justify=tk.LEFT, anchor="w", wraplength=600)
details_label.pack(pady=10)

root.mainloop()

# %%
import pandas as pd
import joblib
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
df.fillna("Not Available", inplace=True)  # Replace NaN values with "Not Available"

# Train and save the model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['name'].astype(str))
model = NearestNeighbors(n_neighbors=10, metric='cosine')  # Increased neighbors for better matching
model.fit(X)

joblib.dump((vectorizer, model), r"C:\Users\HP\Downloads\medicine search\medicine_recommender.pkl")

# UI for search with live recommendation
def update_suggestions(*args):
    query = search_var.get().strip().lower()
    if query:
        filtered_df = df[df['name'].str.lower().str.startswith(query)]
        suggestions = filtered_df['name'].tolist()
        listbox.delete(0, tk.END)
        for suggestion in suggestions:
            listbox.insert(tk.END, suggestion)

def display_details(event):
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'].str.lower() == medicine_name.lower()].iloc[0]

        full_details = f"Name: {details['name']}\nPrice: {details['price']}\nManufacturer: {details['manufacturer_name']}\nType: {details['type']}\nComposition: {details['salt_composition']}\nDescription: {details['medicine_desc']}\nSide Effects: {details['side_effects']}"

        # Hide search bar and listbox after selection
        search_entry.pack_forget()
        listbox.pack_forget()

        # Clear and insert text into Text widget
        details_text.config(state=tk.NORMAL)
        details_text.delete("1.0", tk.END)
        details_text.insert(tk.END, full_details)
        details_text.config(state=tk.DISABLED)

root = tk.Tk()
root.title("Medicine Search")

search_var = tk.StringVar()
search_var.trace("w", update_suggestions)

search_entry = ttk.Entry(root, textvariable=search_var, width=50)
search_entry.pack(pady=10)

listbox = tk.Listbox(root, width=50, height=5)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

details_text = tk.Text(root, wrap="word", width=60, height=10)
details_text.pack(pady=10)

root.mainloop()

# %%
import pandas as pd
import joblib
import tkinter as tk
from tkinter import ttk

# Load dataset
file_path = r"C:\Users\HP\Downloads\medicine search\updated_indian_medicine_data.csv"
df = pd.read_csv(file_path)
df.fillna("Not Available", inplace=True)  # Replace NaN values with "Not Available"

# Train and save the model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['name'].astype(str))
model = NearestNeighbors(n_neighbors=10, metric='cosine')  # Increased neighbors for better matching
model.fit(X)

joblib.dump((vectorizer, model), r"C:\Users\HP\Downloads\medicine search\medicine_recommender.pkl")

# UI for search with live recommendation
def update_suggestions(*args):
    query = search_var.get().strip().lower()
    if query:
        filtered_df = df[df['name'].str.lower().str.startswith(query)]
        suggestions = filtered_df['name'].tolist()
        listbox.delete(0, tk.END)
        for suggestion in suggestions:
            listbox.insert(tk.END, suggestion)

def display_details(event):
    selected_index = listbox.curselection()
    if selected_index:
        medicine_name = listbox.get(selected_index)
        details = df[df['name'].str.lower() == medicine_name.lower()].iloc[0]

        # Split description into multiple lines
        description_lines = "\n".join(details['medicine_desc'][i:i+60] for i in range(0, len(details['medicine_desc']), 60))
        full_details = (
            f"Name: {details['name']}\n"
            f"Price: {details['price']}\n"
            f"Manufacturer: {details['manufacturer_name']}\n"
            f"Type: {details['type']}\n"
            f"Composition: {details['salt_composition']}\n"
            f"Description:\n{description_lines}\n"
            f"Side Effects: {details['side_effects']}"
        )

        # Hide search bar and listbox after selection
        search_entry.pack_forget()
        listbox.pack_forget()

        # Clear and insert text into Text widget
        details_text.config(state=tk.NORMAL)
        details_text.delete("1.0", tk.END)
        details_text.insert(tk.END, full_details)
        details_text.config(state=tk.DISABLED)

root = tk.Tk()
root.title("Medicine Search")

search_var = tk.StringVar()
search_var.trace("w", update_suggestions)

search_entry = ttk.Entry(root, textvariable=search_var, width=50)
search_entry.pack(pady=10)

listbox = tk.Listbox(root, width=50, height=5)
listbox.pack()
listbox.bind("<<ListboxSelect>>", display_details)

details_text = tk.Text(root, wrap="word", width=60, height=15)
details_text.pack(pady=10)

root.mainloop()
